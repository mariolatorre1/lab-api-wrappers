# %%
#!pip install spotipy

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Getting the current top songs from Billboard Hot 100

r = requests.get('https://www.billboard.com/charts/hot-100/')
r.status_code
# Out:
# 200

# %%
html = r.content
soup = BeautifulSoup(html, 'html.parser')

# %%
# Creating a data frame with songs and artists from Billboard Hot 100

containers = soup.find_all("div", attrs={"class": "o-chart-results-list-row-container"})

data = []

for container in containers:
    song_name = container.find("h3").get_text(strip=True)
    artist_name = container.find("li", attrs={"class": "lrv-u-width-100p"}).find("span").get_text(strip=True)
    data.append((song_name, artist_name))
    
billboard_chart = pd.DataFrame(data, columns=['Song' , 'Artist'])
billboard_chart
# Out:
#                    Song                                          Artist
# 0            Last Night                                   Morgan Wallen
# 1               Flowers                                     Miley Cyrus
# 2             Kill Bill                                             SZA
# 3           Die For You                      The Weeknd & Ariana Grande
# 4   Boy's A Liar, Pt. 2                      PinkPantheress & Ice Spice
# ..                  ...                                             ...
# 95             Nonsense                               Sabrina Carpenter
# 96                  AMG  Gabito Ballesteros, Peso Pluma & Natanael Cano
# 97           Lift Me Up                                         Rihanna
# 98           You Didn't                                     Brett Young
# 99                10:35                     Tiesto Featuring Tate McRae
#
# [100 rows x 2 columns]

# %%
# Tranforming the artists from Billboard chart into a list

billboard_artists = list(billboard_chart['Artist'])
billboard_artists
# Out:
# ['Morgan Wallen',
#  'Miley Cyrus',
#  'SZA',
#  'The Weeknd & Ariana Grande',
#  'PinkPantheress & Ice Spice',
#  'Metro Boomin, The Weeknd & 21 Savage',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Taylor Swift',
#  'Nicki Minaj',
#  'Morgan Wallen',
#  'Morgan Wallen Featuring Eric Church',
#  'Sam Smith & Kim Petras',
#  'Karol G x Shakira',
#  'Morgan Wallen',
#  'Rema & Selena Gomez',
#  'Bailey Zimmerman',
#  'David Guetta & Bebe Rexha',
#  'Lil Uzi Vert',
#  'Harry Styles',
#  'Coi Leray',
#  'Beyonce',
#  'Chris Brown',
#  'Morgan Wallen',
#  'Kane Brown With Katelyn Brown',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Taylor Swift',
#  'Morgan Wallen',
#  'RAYE Featuring 070 Shake',
#  'Drake & 21 Savage',
#  'Morgan Wallen',
#  'Luke Combs',
#  'Miguel',
#  'Morgan Wallen',
#  'Stephen Sanchez',
#  'Morgan Wallen Featuring ERNEST',
#  'Morgan Wallen',
#  'Zach Bryan',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Metro Boomin, Future & Chris Brown',
#  'SZA',
#  'Morgan Wallen Featuring HARDY',
#  'Morgan Wallen',
#  'JVKE',
#  'SZA',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Lainey Wilson',
#  'Morgan Wallen',
#  'Meghan Trainor',
#  'HARDY Featuring Lainey Wilson',
#  'Morgan Wallen',
#  'j-hope With J. Cole',
#  'Morgan Wallen',
#  'Superstar Pride',
#  'Morgan Wallen',
#  'Fuerza Regida X Grupo Frontera',
#  'Morgan Wallen',
#  'Lady Gaga',
#  'Toosii',
#  'Drake & 21 Savage',
#  'Morgan Wallen',
#  'Bizarrap & Shakira',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'SZA',
#  'Luke Combs',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Morgan Wallen',
#  'Lizzo Featuring SZA',
#  'Carly Pearce',
#  'Lizzy McAlpine',
#  'Corey Kent',
#  'Lil Uzi Vert',
#  'Parker McCollum',
#  'Jordan Davis',
#  'Ice Spice',
#  'Lil Baby',
#  'Zach Bryan Featuring Maggie Rogers',
#  'The Kid LAROI',
#  'Don Toliver Featuring Justin Bieber & Future',
#  'Carin Leon X Grupo Frontera',
#  'Megan Moroney',
#  'SZA',
#  'Karol G x Romeo Santos',
#  'Metro Boomin, Travis Scott & Young Thug',
#  'Lil Baby Featuring Fridayy',
#  'Sabrina Carpenter',
#  'Gabito Ballesteros, Peso Pluma & Natanael Cano',
#  'Rihanna',
#  'Brett Young',
#  'Tiesto Featuring Tate McRae']

# %%
# Getting the top songs of 2022 from NPR 

r = requests.get('https://www.npr.org/2022/12/15/1135802083/100-best-songs-2022-page-1')
r.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
pages = [i.get('href') for i in soup.find('font', attrs={'style': "font-family:Gotham SSm,Helvetica,Arial,sans-serif;font-size:16px"}).find_all('a')] 
page_1 = ['/2022/12/15/1135802083/100-best-songs-2022-page-1']

# %%
starts = page_1 + pages
rev_starts = starts[::-1]
rev_starts
# Out:
# ['/2022/12/15/1135804266/100-best-songs-2022-page-5',
#  '/2022/12/15/1135803900/100-best-songs-2022-page-4',
#  '/2022/12/15/1135803422/100-best-songs-2022-page-3',
#  '/2022/12/15/1135802978/100-best-songs-2022-page-2',
#  '/2022/12/15/1135802083/100-best-songs-2022-page-1']

# %%
# Creating a data frame with songs and artists from NPR Best Songs fo 2022

data = []
artist_name = []
song_name = []

for start in rev_starts:
    r = requests.get(f'https://www.npr.org{start}')
    soup = BeautifulSoup(r.content, 'html.parser')
    songs = [i.get_text(strip=True) for i in soup.find_all('h3', attrs={'class': "edTag"})]
    artist_name.extend(songs[:-1:2][::-1]) 
    song_name.extend(songs[1::2][::-1])
    
data = zip(song_name, artist_name)

npr_chart = pd.DataFrame(data, columns=['Song' , 'Artist'])
npr_chart
# Out:
#                            Song                         Artist
# 0           "F.N.F. (Let's Go)"             Hitkidd & GloRilla
# 1             "ALIEN SUPERSTAR"                        Beyoncé
# 2                   "El Apagón"                      Bad Bunny
# 3                      "Runner"                         Alex G
# 4                       "SAOKO"                        ROSALÍA
# ..                          ...                            ...
# 95                  "Shakedhat"  Zahsosaa, D STURDY & DJ Crazy
# 96          "Middle of a Heart"               Adeem the Artist
# 97     "Leave It Alone (Remix)"      Viking Ding Dong x Ravi B
# 98  "Attention For It Radiates"              Ian William Craig
# 99                    "Gorilla"                    Little Simz
#
# [100 rows x 2 columns]

# %%
# Tranforming the artists from NPR chart into a list

npr_artists = list(npr_chart['Artist'])
npr_artists
# Out:
# ['Hitkidd & GloRilla',
#  'Beyoncé',
#  'Bad Bunny',
#  'Alex G',
#  'ROSALÍA',
#  'Gunna & Future feat. Young Thug',
#  'Paramore',
#  'MUNA',
#  'Joyce Wrice x KAYTRANADA',
#  'Steve Lacy',
#  'Stromae',
#  'Harry Styles',
#  'Fontaines D.C.',
#  'Zach Bryan',
#  'SZA',
#  'Lizzo',
#  'Fireboy DML & Asake',
#  'Plains',
#  'Third Coast Percussion',
#  'Molly Nilsson',
#  'Omar Apollo',
#  "Let's Eat Grandma",
#  'The Beths',
#  'Megan Thee Stallion',
#  'Ethel Cain',
#  'Makaya McCraven',
#  'Kevin Morby',
#  'Porridge Radio',
#  'Hermanos Gutiérrez',
#  'SiR feat. Scribz Riley',
#  'Koffee',
#  'Hikaru Utada',
#  'Taylor Swift',
#  'Julia Bullock',
#  'Doechii',
#  'Joan Shelley feat. Bill Callahan',
#  'NxWorries feat. H.E.R.',
#  'Joy Orbison x Overmono feat. ABRA',
#  'Ice Spice',
#  'Syd feat. Lucky Daye',
#  'Sean Shibe',
#  'Anna Butterss',
#  'Rico Nasty',
#  'Maggie Rogers',
#  'Julius Rodriguez',
#  'Fly Anakin',
#  'Sudan Archives',
#  'Kendrick Lamar',
#  'Flo Milli',
#  'LE SSERAFIM',
#  'Soccer Mommy',
#  'LF System',
#  'Lil Yachty',
#  'Víkingur Ólafsson',
#  'Yahritza y Su Esencia',
#  'Tommy McLain feat. Elvis Costello',
#  'Regina Spektor',
#  'Sky Ferreira',
#  'Hyd',
#  'Björk',
#  'beabadoobee',
#  'Denzel Curry',
#  'Jazmine Sullivan',
#  'Tove Lo',
#  'Vince Staples',
#  'KAROL G',
#  'Nduduzo Makhathini',
#  'Khruangbin & Leon Bridges',
#  'Black Country, New Road',
#  'Molly Tuttle & Golden Highway',
#  'Julia Jacklin',
#  'La Doña',
#  'Madison Cunningham',
#  'Black Sherif',
#  'Patricia Brennan',
#  'DJ Python',
#  'Beth Orton',
#  'Caroline Shaw & Attacca Quartet',
#  'Anna Tivel',
#  'The 1975',
#  'Ari Lennox',
#  'Disclosure feat. RAYE',
#  'Ayra Starr',
#  'Joyce',
#  'NewJeans',
#  'The Mountain Goats',
#  'Leyla McCalla',
#  'Mary Halvorson',
#  'Guitarricadelafuente',
#  'Straw Man Army',
#  'Tyler Childers',
#  'Pigeon Pit',
#  'Rema',
#  'DOMi & JD BECK',
#  'Gabriels',
#  'Zahsosaa, D STURDY & DJ Crazy',
#  'Adeem the Artist',
#  'Viking Ding Dong x Ravi B',
#  'Ian William Craig',
#  'Little Simz']

# %%
# Accessing Spotify API

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="39cf95fbc68a4b88b5d12c27fddd262a",
                                                           client_secret="845e5a64cd79477d8ca382e374486a1b"))

# %%
# Getting track ids, song names and audio features from artists

def get_audio_features(artist):
    results = sp.search(q=f'artist:{artist}', limit=50)
    track_ids = [track['id'] for track in results['tracks']['items']]
    song_names = [track['name'] for track in results['tracks']['items']]
    
    if song_names:
        audio_features = sp.audio_features(track_ids)
        if audio_features:
            try:
                df = pd.DataFrame(audio_features)
                df['artist'] = artist
                df['song name'] = song_names
                return df
            except Exception as e:
                print(e)

# %%
# Using artists from Billboard Hot 100 to create a data frame with their songs' audio features

artists = billboard_artists

df = pd.DataFrame()

for artist in artists:
    df_artist = get_audio_features(artist)
    if df_artist is not None:
        df = pd.concat([df, df_artist])
    
df_billboard_artists = df.reset_index(drop=True)
df_billboard_artists
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.517   0.675    6    -5.382     1       0.0357       0.45900
# 1            0.492   0.675    6    -5.456     1       0.0389       0.46700
# 2            0.641   0.803    6    -5.781     0       0.0286       0.00232
# 3            0.656   0.757    3    -5.775     0       0.0308       0.49200
# 4            0.498   0.764    4    -5.006     1       0.0309       0.12300
# ...            ...     ...  ...       ...   ...          ...           ...
# 3602         0.505   0.722    8    -5.148     1       0.0326       0.02800
# 3603         0.621   0.613    3    -8.778     1       0.0265       0.03650
# 3604         0.429   0.458    2    -6.163     1       0.0346       0.73200
# 3605         0.308   0.739    7    -5.481     1       0.0404       0.03890
# 3606         0.566   0.765    2    -6.337     1       0.0439       0.02480
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1510    0.518  203.853  audio_features
# 1             0.000000    0.1420    0.478  203.759  audio_features
# 2             0.000004    0.3610    0.671  121.086  audio_features
# 3             0.000000    0.1170    0.429  139.971  audio_features
# 4             0.000031    0.1190    0.489  147.984  audio_features
# ...                ...       ...      ...      ...             ...
# 3602          0.000000    0.1050    0.723  160.041  audio_features
# 3603          0.010400    0.1230    0.339  110.002  audio_features
# 3604          0.000000    0.1080    0.506  148.337  audio_features
# 3605          0.000017    0.2400    0.572   69.938  audio_features
# 3606          0.000000    0.0783    0.604  156.036  audio_features
#
#                           id                                   uri  \
# 0     59uQI0PADDKeE6UZDTJEe8  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 1     7K3BhSpAxZBznislvUMVtn  spotify:track:7K3BhSpAxZBznislvUMVtn
# 2     2YVlDlk2zRceefo6XlC6DX  spotify:track:2YVlDlk2zRceefo6XlC6DX
# 3     0PAcdVzhPO4gq1Iym9ESnK  spotify:track:0PAcdVzhPO4gq1Iym9ESnK
# 4     73zawW1ttszLRgT9By826D  spotify:track:73zawW1ttszLRgT9By826D
# ...                      ...                                   ...
# 3602  3S1ml6NqVkVBjYNB8QgXE7  spotify:track:3S1ml6NqVkVBjYNB8QgXE7
# 3603  11hil3T4O8IqmSUQ4HoOpY  spotify:track:11hil3T4O8IqmSUQ4HoOpY
# 3604  15rzB9pYy9vOrbI8Lo0iXG  spotify:track:15rzB9pYy9vOrbI8Lo0iXG
# 3605  6RbVP4qyOctqbg10v3WEJh  spotify:track:6RbVP4qyOctqbg10v3WEJh
# 3606  2Af5r45Ldo5KODQG2frUzw  spotify:track:2Af5r45Ldo5KODQG2frUzw
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 1     https://api.spotify.com/v1/tracks/7K3BhSpAxZBz...
# 2     https://api.spotify.com/v1/tracks/2YVlDlk2zRce...
# 3     https://api.spotify.com/v1/tracks/0PAcdVzhPO4g...
# 4     https://api.spotify.com/v1/tracks/73zawW1ttszL...
# ...                                                 ...
# 3602  https://api.spotify.com/v1/tracks/3S1ml6NqVkVB...
# 3603  https://api.spotify.com/v1/tracks/11hil3T4O8Iq...
# 3604  https://api.spotify.com/v1/tracks/15rzB9pYy9vO...
# 3605  https://api.spotify.com/v1/tracks/6RbVP4qyOctq...
# 3606  https://api.spotify.com/v1/tracks/2Af5r45Ldo5K...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/59uQ...       163855
# 1     https://api.spotify.com/v1/audio-analysis/7K3B...       163855
# 2     https://api.spotify.com/v1/audio-analysis/2YVl...       158004
# 3     https://api.spotify.com/v1/audio-analysis/0PAc...       177388
# 4     https://api.spotify.com/v1/audio-analysis/73za...       191231
# ...                                                 ...          ...
# 3602  https://api.spotify.com/v1/audio-analysis/3S1m...       188280
# 3603  https://api.spotify.com/v1/audio-analysis/11hi...       269293
# 3604  https://api.spotify.com/v1/audio-analysis/15rz...       245947
# 3605  https://api.spotify.com/v1/audio-analysis/6RbV...       206400
# 3606  https://api.spotify.com/v1/audio-analysis/2Af5...       196440
#
#       time_signature         artist  \
# 0                  4  Morgan Wallen
# 1                  4  Morgan Wallen
# 2                  4  Morgan Wallen
# 3                  4  Morgan Wallen
# 4                  4  Morgan Wallen
# ...              ...            ...
# 3602               4    Brett Young
# 3603               4    Brett Young
# 3604               4    Brett Young
# 3605               4    Brett Young
# 3606               4    Brett Young
#
#                                               song name
# 0                                            Last Night
# 1                                            Last Night
# 2                                       Ain’t That Some
# 3                                      Thinkin’ Bout Me
# 4                    Man Made A Bar (feat. Eric Church)
# ...                                                 ...
# 3602                             Runnin’ Away From Home
# 3603                            The Ship And The Bottle
# 3604  Don’t Wanna Write This Song - The Acoustic Ses...
# 3605  Long Way Home - From The Motion Picture “Fathe...
# 3606                                              Catch
#
# [3607 rows x 20 columns]

# %%
# Using artists from NPR to create a data frame with their songs' audio features

artists = npr_artists

df = pd.DataFrame()

for artist in artists:
    df_artist = get_audio_features(artist)
    if df_artist is not None:
        df = pd.concat([df, df_artist])
    
df_npr_artists = df.reset_index(drop=True)
df_npr_artists
# Out:
# 'NoneType' object has no attribute 'keys'
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.864   0.476    1   -10.068     1       0.4360       0.03740
# 1            0.780   0.689    7    -5.668     1       0.1410       0.03680
# 2            0.789   0.614    1    -6.491     1       0.0579       0.00348
# 3            0.646   0.770    2    -6.596     0       0.2260       0.00249
# 4            0.660   0.688    7    -6.340     1       0.0564       0.43400
# ...            ...     ...  ...       ...   ...          ...           ...
# 3837         0.383   0.536    0    -8.432     0       0.2230       0.26600
# 3838         0.541   0.706    4    -6.227     0       0.2170       0.00252
# 3839         0.374   0.771    1    -6.705     1       0.2120       0.33300
# 3840         0.750   0.492    5    -5.928     0       0.1790       0.13700
# 3841         0.635   0.604    1   -10.125     0       0.1910       0.19900
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.3740    0.647  157.144  audio_features
# 1             0.000010    0.0698    0.642  115.042  audio_features
# 2             0.001520    0.2830    0.108  126.035  audio_features
# 3             0.000000    0.0715    0.681   99.165  audio_features
# 4             0.000000    0.4890    0.650  118.050  audio_features
# ...                ...       ...      ...      ...             ...
# 3837          0.000578    0.0624    0.369   88.074  audio_features
# 3838          0.000113    0.1190    0.536  180.781  audio_features
# 3839          0.004350    0.1300    0.336   79.563  audio_features
# 3840          0.000274    0.3540    0.389  162.033  audio_features
# 3841          0.000000    0.0578    0.390  100.127  audio_features
#
#                           id                                   uri  \
# 0     1b0fbclKNyeIDRSJ6zEbe6  spotify:track:1b0fbclKNyeIDRSJ6zEbe6
# 1     1xzi1Jcr7mEi9K2RfzLOqS  spotify:track:1xzi1Jcr7mEi9K2RfzLOqS
# 2     2XMAWynSTIst5KmLSv0Npf  spotify:track:2XMAWynSTIst5KmLSv0Npf
# 3     5IVuqXILoxVWvWEPm82Jxr  spotify:track:5IVuqXILoxVWvWEPm82Jxr
# 4     7eQpbVg3tjHmtdOlAHxaTr  spotify:track:7eQpbVg3tjHmtdOlAHxaTr
# ...                      ...                                   ...
# 3837  5MfpWWRY5ZzgZExDdCILw5  spotify:track:5MfpWWRY5ZzgZExDdCILw5
# 3838  6Zz6sCwWGbadWXFxSFRpVe  spotify:track:6Zz6sCwWGbadWXFxSFRpVe
# 3839  5LJeOvPt1DHfxllkiWZ6wm  spotify:track:5LJeOvPt1DHfxllkiWZ6wm
# 3840  3Q1HNg15qwjOlDy5ia1NJc  spotify:track:3Q1HNg15qwjOlDy5ia1NJc
# 3841  1mMIFLEa1IZJPfM7gVdssx  spotify:track:1mMIFLEa1IZJPfM7gVdssx
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1b0fbclKNyeI...
# 1     https://api.spotify.com/v1/tracks/1xzi1Jcr7mEi...
# 2     https://api.spotify.com/v1/tracks/2XMAWynSTIst...
# 3     https://api.spotify.com/v1/tracks/5IVuqXILoxVW...
# 4     https://api.spotify.com/v1/tracks/7eQpbVg3tjHm...
# ...                                                 ...
# 3837  https://api.spotify.com/v1/tracks/5MfpWWRY5Zzg...
# 3838  https://api.spotify.com/v1/tracks/6Zz6sCwWGbad...
# 3839  https://api.spotify.com/v1/tracks/5LJeOvPt1DHf...
# 3840  https://api.spotify.com/v1/tracks/3Q1HNg15qwjO...
# 3841  https://api.spotify.com/v1/tracks/1mMIFLEa1IZJ...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1b0f...       137580
# 1     https://api.spotify.com/v1/audio-analysis/1xzi...       225389
# 2     https://api.spotify.com/v1/audio-analysis/2XMA...       198898
# 3     https://api.spotify.com/v1/audio-analysis/5IVu...       236133
# 4     https://api.spotify.com/v1/audio-analysis/7eQp...       249407
# ...                                                 ...          ...
# 3837  https://api.spotify.com/v1/audio-analysis/5Mfp...       235248
# 3838  https://api.spotify.com/v1/audio-analysis/6Zz6...       195509
# 3839  https://api.spotify.com/v1/audio-analysis/5LJe...       363483
# 3840  https://api.spotify.com/v1/audio-analysis/3Q1H...       120397
# 3841  https://api.spotify.com/v1/audio-analysis/1mMI...       367201
#
#       time_signature              artist                           song name
# 0                  4  Hitkidd & GloRilla                   F.N.F. (Let's Go)
# 1                  4             Beyoncé                             CUFF IT
# 2                  4             Beyoncé               AMERICA HAS A PROBLEM
# 3                  4             Beyoncé         Crazy In Love (feat. Jay-Z)
# 4                  4             Beyoncé              CUFF IT - WETTER REMIX
# ...              ...                 ...                                 ...
# 3837               4         Little Simz        One In Rotation + Wide Awake
# 3838               4         Little Simz                             Therapy
# 3839               4         Little Simz  Our Conversations w/ Badbadnotgood
# 3840               4         Little Simz                          damn right
# 3841               4         Little Simz                            Problems
#
# [3842 rows x 20 columns]

# %%
# Getting tracks from a playlist

def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']

    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

# %%
# Getting artists from a playlist so I can later get those artists' top songs info

def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
# Getting the artists from Spotify Top 50 chart playlist

artists_sp_top50 = get_artists_from_playlist("37i9dQZEVXbNG2KDcFcKOF")
artists_sp_top50
# Out:
# ['OneRepublic',
#  'Harry Styles',
#  'Kim Petras',
#  'Chris Brown',
#  'SZA',
#  'Gorillaz',
#  'Nico Valdi',
#  'Selena Gomez',
#  'Bizarrap',
#  'Ice Spice',
#  'RAYE',
#  'Morgan Wallen',
#  'Arctic Monkeys',
#  'Grupo Frontera',
#  'Bad Bunny',
#  'David Guetta',
#  'LiL CaKe',
#  'Arcángel',
#  'Bebe Rexha',
#  'Em Beihold',
#  'Fuerza Regida',
#  'Chencho Corleone',
#  'Lil Uzi Vert',
#  'Migrantes',
#  'Lizzy McAlpine',
#  'Rema',
#  'j-hope',
#  'NewJeans',
#  'The Weeknd',
#  '21 Savage',
#  'Shakira',
#  'PinkPantheress',
#  'Tom Odell',
#  'AgroPlay',
#  'Peso Pluma',
#  '070 Shake',
#  'Ariana Grande',
#  'Romeo Santos',
#  'Metro Boomin',
#  'd4vd',
#  'Feid',
#  'Miguel',
#  'Manuel Turizo',
#  'Stephen Sanchez',
#  'Imagine Dragons',
#  'Natanael Cano',
#  'Drake',
#  'J. Cole',
#  'Eminem',
#  'Daft Punk',
#  'Miley Cyrus',
#  'Gabito Ballesteros',
#  'Yandel',
#  'Quevedo',
#  'Ana Castela',
#  'JVKE',
#  'Sam Smith',
#  'Taylor Swift',
#  'KAROL G',
#  'Ozuna',
#  'Coi Leray']

# %%
# Getting audio features from songs of Spotify Top 50 playlist's artists

artists = artists_sp_top50

df = pd.DataFrame()

for artist in artists:
    df_artist = get_audio_features(artist)
    if df_artist is not None:
        df = pd.concat([df, df_artist])
    
df_artists_sp_top50 = df.reset_index(drop=True)
df_artists_sp_top50
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.704   0.797    0    -5.927     1       0.0475       0.08260
# 1            0.664   0.705    1    -4.972     0       0.0382       0.06540
# 2            0.697   0.875    5    -4.621     1       0.0340       0.13700
# 3            0.593   0.740    8    -6.120     1       0.0339       0.36300
# 4            0.516   0.764    2    -6.223     1       0.0366       0.07170
# ...            ...     ...  ...       ...   ...          ...           ...
# 2839         0.784   0.633    4    -7.830     0       0.0438       0.18700
# 2840         0.915   0.827    8    -4.446     0       0.4340       0.20200
# 2841         0.722   0.675    1    -7.344     1       0.4080       0.41900
# 2842         0.791   0.364    6    -7.166     0       0.0691       0.00197
# 2843         0.704   0.717    8    -4.867     1       0.1320       0.30000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000745    0.0546   0.8250  139.994  audio_features
# 1             0.000000    0.1150   0.4770  122.017  audio_features
# 2             0.000000    0.2800   0.7740  140.069  audio_features
# 3             0.000022    0.1020   0.5020  118.008  audio_features
# 4             0.000000    0.1150   0.3760  148.021  audio_features
# ...                ...       ...      ...      ...             ...
# 2839          0.000003    0.1110   0.0589  114.971  audio_features
# 2840          0.001210    0.0656   0.8250  139.898  audio_features
# 2841          0.000000    0.1060   0.7780  139.874  audio_features
# 2842          0.878000    0.0599   0.2260  105.034  audio_features
# 2843          0.000000    0.4280   0.7030  155.949  audio_features
#
#                           id                                   uri  \
# 0     4h9wh7iOZ0GGn8QVp4RAOB  spotify:track:4h9wh7iOZ0GGn8QVp4RAOB
# 1     6sy3LkhNFjJWlaeSMNwQ62  spotify:track:6sy3LkhNFjJWlaeSMNwQ62
# 2     5r43qanLhUCdBj8HN3fa6B  spotify:track:5r43qanLhUCdBj8HN3fa6B
# 3     1NrJYpdAi7uosDRPmSYrsG  spotify:track:1NrJYpdAi7uosDRPmSYrsG
# 4     1NhPKVLsHhFUHIOZ32QnS2  spotify:track:1NhPKVLsHhFUHIOZ32QnS2
# ...                      ...                                   ...
# 2839  3kSjbNmDdq6rgyELhRDUCk  spotify:track:3kSjbNmDdq6rgyELhRDUCk
# 2840  4wNH2VpM24njig7l0ivyfn  spotify:track:4wNH2VpM24njig7l0ivyfn
# 2841  5DeONcxxhHSBnmODMadT5l  spotify:track:5DeONcxxhHSBnmODMadT5l
# 2842  6YsBcMqQJhcDrweHJAga62  spotify:track:6YsBcMqQJhcDrweHJAga62
# 2843  0EH29Rmc5ub2b759ArNxlW  spotify:track:0EH29Rmc5ub2b759ArNxlW
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4h9wh7iOZ0GG...
# 1     https://api.spotify.com/v1/tracks/6sy3LkhNFjJW...
# 2     https://api.spotify.com/v1/tracks/5r43qanLhUCd...
# 3     https://api.spotify.com/v1/tracks/1NrJYpdAi7uo...
# 4     https://api.spotify.com/v1/tracks/1NhPKVLsHhFU...
# ...                                                 ...
# 2839  https://api.spotify.com/v1/tracks/3kSjbNmDdq6r...
# 2840  https://api.spotify.com/v1/tracks/4wNH2VpM24nj...
# 2841  https://api.spotify.com/v1/tracks/5DeONcxxhHSB...
# 2842  https://api.spotify.com/v1/tracks/6YsBcMqQJhcD...
# 2843  https://api.spotify.com/v1/tracks/0EH29Rmc5ub2...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4h9w...       148486
# 1     https://api.spotify.com/v1/audio-analysis/6sy3...       257840
# 2     https://api.spotify.com/v1/audio-analysis/5r43...       163855
# 3     https://api.spotify.com/v1/audio-analysis/1NrJ...       208107
# 4     https://api.spotify.com/v1/audio-analysis/1NhP...       224693
# ...                                                 ...          ...
# 2839  https://api.spotify.com/v1/audio-analysis/3kSj...       120027
# 2840  https://api.spotify.com/v1/audio-analysis/4wNH...       178413
# 2841  https://api.spotify.com/v1/audio-analysis/5DeO...       168720
# 2842  https://api.spotify.com/v1/audio-analysis/6YsB...       139560
# 2843  https://api.spotify.com/v1/audio-analysis/0EH2...       148462
#
#       time_signature       artist                                   song name
# 0                  4  OneRepublic                             I Ain't Worried
# 1                  4  OneRepublic                              Counting Stars
# 2                  4  OneRepublic                                    Sunshine
# 3                  4  OneRepublic                                   Apologize
# 4                  4  OneRepublic                                     Secrets
# ...              ...          ...                                         ...
# 2839               4    Coi Leray                                    Good Day
# 2840               4    Coi Leray              Blick Blick (with Nicki Minaj)
# 2841               4    Coi Leray  Mountains (with Fivio Foreign & Young M.A)
# 2842               4    Coi Leray                      Players - Instrumental
# 2843               4    Coi Leray                                   Do Better
#
# [2844 rows x 20 columns]

# %%
#df_artists_sp_top50 = df_artists_sp_top50.drop('0', axis=1, inplace=True,)

# %%
# Getting the artists from Spotify Viral 50 chart playlist

artists_sp_viral50 = get_artists_from_playlist("37i9dQZEVXbLiRSasKsNU9")
artists_sp_viral50
# Out:
# ['Bayriton',
#  'Ice Spice',
#  'Milo j',
#  'thiarajxtt',
#  'Lumi Athena',
#  'Big One',
#  'kurffew',
#  'Zach Templar',
#  'Emilia',
#  'Mohit Lalwani',
#  'Lil Uzi Vert',
#  'Jairo Vera',
#  'Jassa Dhillon',
#  'Sharn',
#  'Mae Stephens',
#  'keshi',
#  'AgroPlay',
#  'Gringuitos Records',
#  'NF',
#  'Bharat Kamal',
#  'Daisy Jones & The Six',
#  'Superstar Pride',
#  'Yuri Redicopa',
#  'Lil Geniuz',
#  'Jogja Hip Hop Foundation',
#  'Taiu',
#  'Tommy Boysen',
#  'BLOK3',
#  'Young Miko',
#  'Toosii',
#  'The Paul',
#  'Semicenk',
#  'Shiloh Dynasty',
#  'Tangerine Kitty',
#  'Käärijä',
#  'CORBAL',
#  'yungcihad',
#  'Morgan Wallen',
#  'Ronghao Li',
#  '40k',
#  'ARIZONATEARS',
#  'GenriX',
#  'Callejero Fino',
#  'El Rey',
#  'Bayron Fire',
#  'TINI',
#  'Jann',
#  'Lizzy McAlpine',
#  'Jimin',
#  'Raim Laode',
#  'Niall Horan',
#  'Kaifi Khalil',
#  'PinkPantheress',
#  'sped up nightcore',
#  'Jeff Grecia',
#  'beabadoobee',
#  'SWIRF',
#  'Kenia OS',
#  'Nickoog Clk',
#  'B4TU INC.',
#  'Dj Bnão',
#  'Ana Castela',
#  'TV Girl',
#  'Gino Mella',
#  'Balbi El Chamako',
#  'jnhygs',
#  'Augusto e Rafael',
#  'Qimp',
#  'Gabriela Rocha',
#  'XG',
#  'Reynmen',
#  'Clara La San',
#  'Heyek Crew',
#  'Hozwal',
#  'Dilaw',
#  'Chino Pacas',
#  'Treyce']

# %%
# Getting audio features from songs of Spotify Viral 50 playlist's artists

artists = artists_sp_viral50

df = pd.DataFrame()

for artist in artists:
    df_artist = get_audio_features(artist)
    if df_artist is not None:
        df = pd.concat([df, df_artist])
    
df_artists_sp_viral50 = df.reset_index(drop=True)
df_artists_sp_viral50
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.817   0.600    4    -7.996     0       0.0538       0.37100
# 1            0.839   0.493    4    -9.635     0       0.0710       0.08300
# 2            0.804   0.720    1    -7.929     0       0.0653       0.11500
# 3            0.861   0.620    7    -5.807     0       0.0544       0.05050
# 4            0.690   0.601    5    -6.877     0       0.0484       0.39700
# ...            ...     ...  ...       ...   ...          ...           ...
# 2473         0.900   0.693    8    -3.892     0       0.0651       0.00753
# 2474         0.846   0.400   10   -14.990     0       0.1270       0.15400
# 2475         0.769   0.372   11   -14.401     0       0.0689       0.09320
# 2476         0.887   0.443   11    -9.045     0       0.1630       0.18000
# 2477         0.824   0.458    0   -13.791     1       0.1330       0.37800
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1750    0.490   91.962  audio_features
# 1             0.008680    0.1570    0.638   94.984  audio_features
# 2             0.003110    0.0976    0.791   94.017  audio_features
# 3             0.000000    0.0940    0.920   94.999  audio_features
# 4             0.000489    0.2330    0.735  170.066  audio_features
# ...                ...       ...      ...      ...             ...
# 2473          0.000000    0.0747    0.951  130.220  audio_features
# 2474          0.000000    0.0509    0.861   96.949  audio_features
# 2475          0.001660    0.0882    0.532  136.456  audio_features
# 2476          0.000000    0.0601    0.728   95.185  audio_features
# 2477          0.000016    0.2010    0.851   98.033  audio_features
#
#                           id                                   uri  \
# 0     4l1SYWEm3bCpoLb07qsKRT  spotify:track:4l1SYWEm3bCpoLb07qsKRT
# 1     2DulMiBsjxcjwYuPkMYuMP  spotify:track:2DulMiBsjxcjwYuPkMYuMP
# 2     1VS2eWdddPy19Gg8crvvxx  spotify:track:1VS2eWdddPy19Gg8crvvxx
# 3     6aJ2k0EquJJKpLtDjhAXNM  spotify:track:6aJ2k0EquJJKpLtDjhAXNM
# 4     7zVg5jaLZhM0JiINyw1YAg  spotify:track:7zVg5jaLZhM0JiINyw1YAg
# ...                      ...                                   ...
# 2473  76ZsC12dozqFyutp0swDmA  spotify:track:76ZsC12dozqFyutp0swDmA
# 2474  40Zk0gbkmPE4h9oDaPYcT7  spotify:track:40Zk0gbkmPE4h9oDaPYcT7
# 2475  1WVgBwFvgfG2t7nZ0ouetB  spotify:track:1WVgBwFvgfG2t7nZ0ouetB
# 2476  7bdyAzlkeqq5HzljF6v243  spotify:track:7bdyAzlkeqq5HzljF6v243
# 2477  6bdPJ3Wp9lcKWkn08C587j  spotify:track:6bdPJ3Wp9lcKWkn08C587j
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/4l1SYWEm3bCp...
# 1     https://api.spotify.com/v1/tracks/2DulMiBsjxcj...
# 2     https://api.spotify.com/v1/tracks/1VS2eWdddPy1...
# 3     https://api.spotify.com/v1/tracks/6aJ2k0EquJJK...
# 4     https://api.spotify.com/v1/tracks/7zVg5jaLZhM0...
# ...                                                 ...
# 2473  https://api.spotify.com/v1/tracks/76ZsC12dozqF...
# 2474  https://api.spotify.com/v1/tracks/40Zk0gbkmPE4...
# 2475  https://api.spotify.com/v1/tracks/1WVgBwFvgfG2...
# 2476  https://api.spotify.com/v1/tracks/7bdyAzlkeqq5...
# 2477  https://api.spotify.com/v1/tracks/6bdPJ3Wp9lcK...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/4l1S...       189633
# 1     https://api.spotify.com/v1/audio-analysis/2Dul...       169326
# 2     https://api.spotify.com/v1/audio-analysis/1VS2...       163847
# 3     https://api.spotify.com/v1/audio-analysis/6aJ2...       153348
# 4     https://api.spotify.com/v1/audio-analysis/7zVg...       195993
# ...                                                 ...          ...
# 2473  https://api.spotify.com/v1/audio-analysis/76Zs...       243440
# 2474  https://api.spotify.com/v1/audio-analysis/40Zk...       191587
# 2475  https://api.spotify.com/v1/audio-analysis/1WVg...       253053
# 2476  https://api.spotify.com/v1/audio-analysis/7bdy...       176147
# 2477  https://api.spotify.com/v1/audio-analysis/6bdP...       180227
#
#       time_signature    artist                  song name
# 0                  4  Bayriton                 Tus Ojitos
# 1                  4  Bayriton      El Motivo de Mi Carro
# 2                  4  Bayriton              Te Quiero Ver
# 3                  4  Bayriton              Si Tu Quieres
# 4                  4  Bayriton             No Se Que Paso
# ...              ...       ...                        ...
# 2473               4    Treyce  All In My Game - Thug Mix
# 2474               4    Treyce           Ghetto Superstar
# 2475               4    Treyce          Come Into My Love
# 2476               4    Treyce  If She's Just Your Friend
# 2477               4    Treyce                   No Doubt
#
# [2478 rows x 20 columns]

# %%
# Concatenating all databases into one

df_all_songs = pd.concat([df_billboard_artists, df_npr_artists, df_artists_sp_top50, df_artists_sp_viral50])

# %%
df_all_songs
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.517   0.675    6    -5.382     1       0.0357       0.45900
# 1            0.492   0.675    6    -5.456     1       0.0389       0.46700
# 2            0.641   0.803    6    -5.781     0       0.0286       0.00232
# 3            0.656   0.757    3    -5.775     0       0.0308       0.49200
# 4            0.498   0.764    4    -5.006     1       0.0309       0.12300
# ...            ...     ...  ...       ...   ...          ...           ...
# 2473         0.900   0.693    8    -3.892     0       0.0651       0.00753
# 2474         0.846   0.400   10   -14.990     0       0.1270       0.15400
# 2475         0.769   0.372   11   -14.401     0       0.0689       0.09320
# 2476         0.887   0.443   11    -9.045     0       0.1630       0.18000
# 2477         0.824   0.458    0   -13.791     1       0.1330       0.37800
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1510    0.518  203.853  audio_features
# 1             0.000000    0.1420    0.478  203.759  audio_features
# 2             0.000004    0.3610    0.671  121.086  audio_features
# 3             0.000000    0.1170    0.429  139.971  audio_features
# 4             0.000031    0.1190    0.489  147.984  audio_features
# ...                ...       ...      ...      ...             ...
# 2473          0.000000    0.0747    0.951  130.220  audio_features
# 2474          0.000000    0.0509    0.861   96.949  audio_features
# 2475          0.001660    0.0882    0.532  136.456  audio_features
# 2476          0.000000    0.0601    0.728   95.185  audio_features
# 2477          0.000016    0.2010    0.851   98.033  audio_features
#
#                           id                                   uri  \
# 0     59uQI0PADDKeE6UZDTJEe8  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 1     7K3BhSpAxZBznislvUMVtn  spotify:track:7K3BhSpAxZBznislvUMVtn
# 2     2YVlDlk2zRceefo6XlC6DX  spotify:track:2YVlDlk2zRceefo6XlC6DX
# 3     0PAcdVzhPO4gq1Iym9ESnK  spotify:track:0PAcdVzhPO4gq1Iym9ESnK
# 4     73zawW1ttszLRgT9By826D  spotify:track:73zawW1ttszLRgT9By826D
# ...                      ...                                   ...
# 2473  76ZsC12dozqFyutp0swDmA  spotify:track:76ZsC12dozqFyutp0swDmA
# 2474  40Zk0gbkmPE4h9oDaPYcT7  spotify:track:40Zk0gbkmPE4h9oDaPYcT7
# 2475  1WVgBwFvgfG2t7nZ0ouetB  spotify:track:1WVgBwFvgfG2t7nZ0ouetB
# 2476  7bdyAzlkeqq5HzljF6v243  spotify:track:7bdyAzlkeqq5HzljF6v243
# 2477  6bdPJ3Wp9lcKWkn08C587j  spotify:track:6bdPJ3Wp9lcKWkn08C587j
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 1     https://api.spotify.com/v1/tracks/7K3BhSpAxZBz...
# 2     https://api.spotify.com/v1/tracks/2YVlDlk2zRce...
# 3     https://api.spotify.com/v1/tracks/0PAcdVzhPO4g...
# 4     https://api.spotify.com/v1/tracks/73zawW1ttszL...
# ...                                                 ...
# 2473  https://api.spotify.com/v1/tracks/76ZsC12dozqF...
# 2474  https://api.spotify.com/v1/tracks/40Zk0gbkmPE4...
# 2475  https://api.spotify.com/v1/tracks/1WVgBwFvgfG2...
# 2476  https://api.spotify.com/v1/tracks/7bdyAzlkeqq5...
# 2477  https://api.spotify.com/v1/tracks/6bdPJ3Wp9lcK...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/59uQ...       163855
# 1     https://api.spotify.com/v1/audio-analysis/7K3B...       163855
# 2     https://api.spotify.com/v1/audio-analysis/2YVl...       158004
# 3     https://api.spotify.com/v1/audio-analysis/0PAc...       177388
# 4     https://api.spotify.com/v1/audio-analysis/73za...       191231
# ...                                                 ...          ...
# 2473  https://api.spotify.com/v1/audio-analysis/76Zs...       243440
# 2474  https://api.spotify.com/v1/audio-analysis/40Zk...       191587
# 2475  https://api.spotify.com/v1/audio-analysis/1WVg...       253053
# 2476  https://api.spotify.com/v1/audio-analysis/7bdy...       176147
# 2477  https://api.spotify.com/v1/audio-analysis/6bdP...       180227
#
#       time_signature         artist                           song name
# 0                  4  Morgan Wallen                          Last Night
# 1                  4  Morgan Wallen                          Last Night
# 2                  4  Morgan Wallen                     Ain’t That Some
# 3                  4  Morgan Wallen                    Thinkin’ Bout Me
# 4                  4  Morgan Wallen  Man Made A Bar (feat. Eric Church)
# ...              ...            ...                                 ...
# 2473               4         Treyce           All In My Game - Thug Mix
# 2474               4         Treyce                    Ghetto Superstar
# 2475               4         Treyce                   Come Into My Love
# 2476               4         Treyce           If She's Just Your Friend
# 2477               4         Treyce                            No Doubt
#
# [12771 rows x 20 columns]

# %%
# Dropping duplicates

df_2 = df_all_songs.drop_duplicates(keep='first')

# %%
# Final database of songs and audio features

df_2
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.517   0.675    6    -5.382     1       0.0357       0.45900
# 1            0.492   0.675    6    -5.456     1       0.0389       0.46700
# 2            0.641   0.803    6    -5.781     0       0.0286       0.00232
# 3            0.656   0.757    3    -5.775     0       0.0308       0.49200
# 4            0.498   0.764    4    -5.006     1       0.0309       0.12300
# ...            ...     ...  ...       ...   ...          ...           ...
# 2473         0.900   0.693    8    -3.892     0       0.0651       0.00753
# 2474         0.846   0.400   10   -14.990     0       0.1270       0.15400
# 2475         0.769   0.372   11   -14.401     0       0.0689       0.09320
# 2476         0.887   0.443   11    -9.045     0       0.1630       0.18000
# 2477         0.824   0.458    0   -13.791     1       0.1330       0.37800
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1510    0.518  203.853  audio_features
# 1             0.000000    0.1420    0.478  203.759  audio_features
# 2             0.000004    0.3610    0.671  121.086  audio_features
# 3             0.000000    0.1170    0.429  139.971  audio_features
# 4             0.000031    0.1190    0.489  147.984  audio_features
# ...                ...       ...      ...      ...             ...
# 2473          0.000000    0.0747    0.951  130.220  audio_features
# 2474          0.000000    0.0509    0.861   96.949  audio_features
# 2475          0.001660    0.0882    0.532  136.456  audio_features
# 2476          0.000000    0.0601    0.728   95.185  audio_features
# 2477          0.000016    0.2010    0.851   98.033  audio_features
#
#                           id                                   uri  \
# 0     59uQI0PADDKeE6UZDTJEe8  spotify:track:59uQI0PADDKeE6UZDTJEe8
# 1     7K3BhSpAxZBznislvUMVtn  spotify:track:7K3BhSpAxZBznislvUMVtn
# 2     2YVlDlk2zRceefo6XlC6DX  spotify:track:2YVlDlk2zRceefo6XlC6DX
# 3     0PAcdVzhPO4gq1Iym9ESnK  spotify:track:0PAcdVzhPO4gq1Iym9ESnK
# 4     73zawW1ttszLRgT9By826D  spotify:track:73zawW1ttszLRgT9By826D
# ...                      ...                                   ...
# 2473  76ZsC12dozqFyutp0swDmA  spotify:track:76ZsC12dozqFyutp0swDmA
# 2474  40Zk0gbkmPE4h9oDaPYcT7  spotify:track:40Zk0gbkmPE4h9oDaPYcT7
# 2475  1WVgBwFvgfG2t7nZ0ouetB  spotify:track:1WVgBwFvgfG2t7nZ0ouetB
# 2476  7bdyAzlkeqq5HzljF6v243  spotify:track:7bdyAzlkeqq5HzljF6v243
# 2477  6bdPJ3Wp9lcKWkn08C587j  spotify:track:6bdPJ3Wp9lcKWkn08C587j
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/59uQI0PADDKe...
# 1     https://api.spotify.com/v1/tracks/7K3BhSpAxZBz...
# 2     https://api.spotify.com/v1/tracks/2YVlDlk2zRce...
# 3     https://api.spotify.com/v1/tracks/0PAcdVzhPO4g...
# 4     https://api.spotify.com/v1/tracks/73zawW1ttszL...
# ...                                                 ...
# 2473  https://api.spotify.com/v1/tracks/76ZsC12dozqF...
# 2474  https://api.spotify.com/v1/tracks/40Zk0gbkmPE4...
# 2475  https://api.spotify.com/v1/tracks/1WVgBwFvgfG2...
# 2476  https://api.spotify.com/v1/tracks/7bdyAzlkeqq5...
# 2477  https://api.spotify.com/v1/tracks/6bdPJ3Wp9lcK...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/59uQ...       163855
# 1     https://api.spotify.com/v1/audio-analysis/7K3B...       163855
# 2     https://api.spotify.com/v1/audio-analysis/2YVl...       158004
# 3     https://api.spotify.com/v1/audio-analysis/0PAc...       177388
# 4     https://api.spotify.com/v1/audio-analysis/73za...       191231
# ...                                                 ...          ...
# 2473  https://api.spotify.com/v1/audio-analysis/76Zs...       243440
# 2474  https://api.spotify.com/v1/audio-analysis/40Zk...       191587
# 2475  https://api.spotify.com/v1/audio-analysis/1WVg...       253053
# 2476  https://api.spotify.com/v1/audio-analysis/7bdy...       176147
# 2477  https://api.spotify.com/v1/audio-analysis/6bdP...       180227
#
#       time_signature         artist                           song name
# 0                  4  Morgan Wallen                          Last Night
# 1                  4  Morgan Wallen                          Last Night
# 2                  4  Morgan Wallen                     Ain’t That Some
# 3                  4  Morgan Wallen                    Thinkin’ Bout Me
# 4                  4  Morgan Wallen  Man Made A Bar (feat. Eric Church)
# ...              ...            ...                                 ...
# 2473               4         Treyce           All In My Game - Thug Mix
# 2474               4         Treyce                    Ghetto Superstar
# 2475               4         Treyce                   Come Into My Love
# 2476               4         Treyce           If She's Just Your Friend
# 2477               4         Treyce                            No Doubt
#
# [9346 rows x 20 columns]

# %%
results = sp.search(q='artist:Madonna', limit=10, type='track')
results

# %%
results.keys()

# %%
for song in results["tracks"]["items"]:
    print(song['name'])

# %%
results = sp.user_playlist_tracks("spotify", "37i9dQZF1E38Otlfp7fIkm")
tracks = results['items'] 

len(tracks)

# %%
for song in sp.user_playlist_tracks("spotify", "37i9dQZF1E38Otlfp7fIkm")['items']: 
    print(song['track']['name'])
